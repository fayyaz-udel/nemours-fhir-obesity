# %%
import pandas as pd

# %%
fid=pd.read_csv('fid.csv',header=0)

# %%
fid=fid.drop_duplicates()

# %%
fid.head()
# Out:
#                                                 fact            fid
# 0  Male|Non-Hispanic or Latino|Black or African A...         DEMO_0
# 1                               Body height Measured   MEAS_3023540
# 2                               Body weight Measured   MEAS_3013762
# 3  Body mass index (BMI) [Percentile] Per age and...  MEAS_40762638
# 4  Initial comprehensive preventive medicine eval...   PROC_2514516

# %%
fid[fid['fact'].str.contains("hypertension")]#['fact'].unique()
# Out:
#                                                     fact            fid
# 1232                              Secondary hypertension    COND_319826
# 1968   Elevated blood-pressure reading without diagno...    COND_141693
# 3628                              Essential hypertension    COND_320128
# 5536                       Benign essential hypertension    COND_312648
# 5753                                     Prehypertension  COND_45765798
# 7299                              Transient hypertension   COND_4199306
# 10033  Craniectomy or craniotomy, decompressive, with...   PROC_2110426
# 11148                                  H/O: hypertension   COND_4058286
# 11691                   Secondary pulmonary hypertension   COND_4339214
# 12013                             Pulmonary hypertension   COND_4322024
# 12014   Persistent pulmonary hypertension of the newborn   COND_4121462
# 12251  Chronic kidney disease stage 5 due to hyperten...  COND_44782690
# ...

# %%
fid[fid['fact'].str.contains("blood pressure")]
# Out:
#                                                     fact            fid
# 50                               Systolic blood pressure   MEAS_3004249
# 51                              Diastolic blood pressure   MEAS_3012888
# 1147                             Elevated blood pressure   COND_4086587
# 1230                  Mean blood pressure by Noninvasive  MEAS_21492241
# 4683                                  Low blood pressure    COND_317002
# 5320                        Invasive Mean blood pressure  MEAS_21490852
# 6180   Ambulatory blood pressure monitoring, utilizin...   PROC_2313967
# 25792                         Low blood pressure reading    COND_314171
# 27647                              Labile blood pressure   COND_4354255
# 28070          Decreased blood pressure, not hypotension   COND_4132739
# 30287  Ambulatory blood pressure monitoring, utilizin...   PROC_2313970
# 32448  Collection and interpretation of physiologic d...   PROC_2414364
# ...

# %%
fid[fid['fact'].str.contains("Cardiomegaly")]
# Out:
#                               fact           fid
# 16393                 Cardiomegaly   COND_314658
# 32486  Cardiomegaly - hypertensive  COND_4173820

# %%
fid[fid['fact'].str.contains("hypertrophy")]
# Out:
#                                                     fact            fid
# 1201                                     Fat hypertrophy   COND_4033484
# 5654                           Hemihypertrophy of muscle   COND_4093174
# 7827                       Right ventricular hypertrophy   COND_4231591
# 10795                 Adrenal hypertrophy or hyperplasia   COND_4029579
# 10904                       Left ventricular hypertrophy   COND_4184746
# 17304          Hypertensive left ventricular hypertrophy   COND_4322893
# 18178                            Ventricular hypertrophy   COND_4145489
# 18521                   EKG: right ventricle hypertrophy   COND_4065283
# 19710                                 Atrial hypertrophy   COND_4108350
# 24337                         Congenital hemihypertrophy  COND_40402869
# 25039                            Left atrial hypertrophy  COND_40489802
# 28048                               Synovial hypertrophy   COND_4347302
# ...

# %%
fid[fid['fact'].str.contains("Dyslipidemia")]
# Out:
#               fact           fid
# 1816  Dyslipidemia  COND_4159131

# %%
fid[fid['fact'].str.contains("hypertriglyceridemia")]
# Out:
#                                                     fact           fid
# 2948   Mixed hypercholesterolemia and hypertriglyceri...  COND_4030619
# 9115                       Familial hypertriglyceridemia  COND_4142496
# 30187                       Primary hypertriglyceridemia  COND_4029260

# %%
fid[fid['fact'].str.contains("hypercholesterolemia")]
# Out:
#                                                     fact           fid
# 1435                           Pure hypercholesterolemia   COND_437827
# 2948   Mixed hypercholesterolemia and hypertriglyceri...  COND_4030619
# 12396                      Familial hypercholesterolemia  COND_4134862
# 30675                    History of hypercholesterolemia  COND_4185909

# %%
fid[fid['fact'].str.contains("lipid")]
# Out:
#                                                     fact            fid
# 1816                                        Dyslipidemia   COND_4159131
# 1821                                      Hyperlipidemia    COND_432867
# 3637                    Family history of hyperlipidemia  COND_37119239
# 3697                                Mixed hyperlipidemia    COND_438720
# 7761                  Fat or lipids, feces; quantitative   PROC_2212329
# 11955  Cardiolipin (phospholipid) antibody, each Ig c...   PROC_2212764
# 13692  Phospholipid IgG Ab [Units/volume] in Serum by...   MEAS_3015569
# 16831  aPTT W excess hexagonal phospholipid (StaClot ...   MEAS_3030675
# 17444                                    Increased lipid   COND_4051221
# 17499                       Disorder of lipid metabolism    COND_437530
# 18404    Anti-phosphatidylserine (phospholipid) antibody   PROC_2212765
# 20280     Hyperlipidemia due to type 1 diabetes mellitus  COND_45757432
# ...

# %%
fid[fid['fact'].str.contains("Cholelithiasis")]
# Out:
#                                                     fact           fid
# 3533                     Cholelithiasis with obstruction  COND_4300203
# 11106                 Cholelithiasis without obstruction   COND_444367
# 44262  Cholelithiasis AND cholecystitis with obstruction   COND_195587
# 51910  Cholelithiasis AND cholecystitis without obstr...   COND_201070

# %%
fid[fid['fact'].str.contains("Constipation")]
# Out:
#                                         fact           fid
# 251                             Constipation    COND_75860
# 1135               Constipation - functional  COND_4055110
# 3220      Constipation by outlet obstruction   COND_201905
# 16557  Constipation alternates with diarrhea  COND_4096857
# 29100   Constipation due to neurogenic bowel  COND_4333213

# %%
fid[fid['fact'].str.contains("Gastroesophageal reflux")]
# Out:
#                                                     fact            fid
# 246                      Gastroesophageal reflux disease    COND_318800
# 1647   Gastroesophageal reflux disease without esopha...   COND_4144111
# 2890                       Gastroesophageal reflux study   PROC_2211956
# 7969          Gastroesophageal reflux disease with apnea   COND_4159148
# 18362                   Gastroesophageal reflux in child  COND_36712768
# 26004  Gastroesophageal reflux disease with hiatal he...   COND_4159156

# %%
fid[fid['fact'].str.contains("NAFLD/NASH")]
# Out:
# Empty DataFrame
# Columns: [fact, fid]
# Index: []

# %%
fid[fid['fact'].str.contains("liver enzymes")]
# Out:
#                                                     fact            fid
# 2850                        Elevated liver enzymes level  COND_45769139
# 14250  Elevated liver enzymes level due to cystic fib...  COND_45769146

# %%
fid[fid['fact'].str.contains("Acanthosis nigricans")]
# Out:
#                      fact           fid
# 946  Acanthosis nigricans  COND_4299544

# %%
fid[fid['fact'].str.contains("Diabetes")]
# Out:
#                                                     fact            fid
# 1223   Diabetes outpatient self-management training s...   PROC_2617211
# 1544                               FH: Diabetes mellitus   COND_4051114
# 2269      FH: Diabetes mellitus in first degree relative   COND_4215667
# 7744                                   Diabetes mellitus    COND_201820
# 9908                                  Diabetes insipidus     COND_30968
# 13772           Diabetes mellitus due to cystic fibrosis   COND_4144583
# 14258  Diabetes mellitus associated with cystic fibrosis   COND_4143529
# 21292             Diabetes mellitus without complication   COND_4008576
# 22313  Diabetes outpatient self-management training s...   PROC_2617212
# 24861                          FH: Diabetes in pregnancy   COND_4051249
# 25658  Diabetes mellitus associated with hormonal eti...   COND_4240589
# 36086  Diabetes mellitus associated with pancreatic d...   COND_4178452
# ...

# %%
fid[fid['fact'].str.contains("Prediabetes")]
# Out:
#              fact            fid
# 2951  Prediabetes  COND_37018196

# %%
fid[fid['fact'].str.contains("hemoglobin A1c ")]
# Out:
#                            fact            fid
# 2569  High hemoglobin A1c level  COND_40480694

# %%
fid[fid['fact'].str.contains("Precocious puberty")]
# Out:
#                     fact           fid
# 2692  Precocious puberty  COND_4267558

# %%
fid[fid['fact'].str.contains("Hypothyroidism")]
# Out:
#                                                     fact            fid
# 1343                                      Hypothyroidism    COND_140673
# 5893       Hypothyroidism due to Hashimoto's thyroiditis   COND_4130018
# 11033                      Hypothyroidism caused by drug  COND_37016342
# 15091                                 FH: Hypothyroidism   COND_4114014
# 28305                        Hypothyroidism in pregnancy   COND_4176015
# 37100  Hypothyroidism due to fibrous invasive thyroid...   COND_4192649

# %%
fid[fid['fact'].str.contains("Hypothalamic")]
# Out:
#                                    fact           fid
# 12631             Hypothalamic syndrome  COND_4008579
# 25666  Hypothalamic-adrenal dysfunction  COND_4000054
# 26501       Hypothalamic hypothyroidism  COND_4291925
# 31139         Hypothalamic overactivity  COND_4034994
# 46086                 Hypothalamic mass  COND_4034987
# 48952              Hypothalamic obesity  COND_4220527

# %%
fid[fid['fact'].str.contains("Anxiety")]
# Out:
#                                                     fact           fid
# 500                                              Anxiety   COND_441542
# 972                      Anxiety disorder of adolescence  COND_4242095
# 2406                       Anxiety disorder of childhood  COND_4203449
# 2923                                    Anxiety disorder   COND_442077
# 4021                                       Anxiety state  COND_4113821
# 4465   Anxiety disorder due to a general medical cond...  COND_4199892
# 9049        Anxiety disorder of childhood OR adolescence   COND_433178
# 10169              Anxiety about body function or health  COND_4084699
# 22370                                     Anxiety attack  COND_4115221
# 36944                           Anxiety hyperventilation  COND_4288011

# %%
fid[fid['fact'].str.contains("Depression")]
# Out:
#                                                    fact           fid
# 970                       Depression screening positive   COND_762504
# 8098                                     FH: Depression  COND_4050806
# 11722                     Depression screening negative   COND_762503
# 39987  Depression of left ventricular systolic function  COND_4161569

# %%
fid[fid['fact'].str.contains("Binge eating disorder")]
# Out:
#                         fact           fid
# 14746  Binge eating disorder  COND_4208913

# %%
fid[fid['fact'].str.contains("Developmental delay")]
# Out:
#                                                     fact            fid
# 2698                                 Developmental delay    COND_436077
# 3093          Developmental delay in fine motor function  COND_45766339
# 11186  Developmental delay in receptive-expressive la...  COND_45765561

# %%
fid[fid['fact'].str.contains("ADHD ")]
# Out:
# Empty DataFrame
# Columns: [fact, fid]
# Index: []

# %%
fid[fid['fact'].str.contains("Asthma")]
# Out:
#                                                     fact            fid
# 1411                                              Asthma    COND_317009
# 7036   Asthma-chronic obstructive pulmonary disease o...  COND_46274062
# 9170                                Asthmatic bronchitis   COND_4233784
# 9287                          Asthma night-time symptoms   COND_4191827
# 13899                                     Asthma finding   COND_4308356
# 14921                                    Asthma resolved   COND_4036799
# 16449                  Asthma without status asthmaticus   COND_4206340
# 38952                         Asthma - currently dormant   COND_4207479

# %%
fid[fid['fact'].str.contains("hypoventilation")]
# Out:
#                                                     fact            fid
# 17399      Extreme obesity with alveolar hypoventilation   COND_4100857
# 22289                 Congenital central hypoventilation    COND_319793
# 22300          Central alveolar hypoventilation syndrome   COND_4086499
# 22618                              Sleep hypoventilation  COND_40483220
# 26340  Idiopathic sleep related non-obstructive alveo...  COND_40481299
# 30587         Sleep related hypoventilation or hypoxemia  COND_43021811
# 45510                           Alveolar hypoventilation    COND_440376

# %%
fid[fid['fact'].str.contains("sleep apnea")]
# Out:
#                                            fact            fid
# 107            Obstructive sleep apnea syndrome    COND_442588
# 2442           Obstructive sleep apnea of child  COND_42872388
# 5878               Central sleep apnea syndrome    COND_439794
# 23380             Family history of sleep apnea   COND_4332641
# 23383              Hypersomnia with sleep apnea    COND_439150
# 23411                       Organic sleep apnea  COND_40482247
# 31460                 Insomnia with sleep apnea    COND_434172
# 34038                         Mixed sleep apnea   COND_4043564
# 35437  Severe pediatric obstructive sleep apnea  COND_37109055
# 46775            Primary sleep apnea of newborn   COND_4262580

# %%
fh=list(fid[fid['fact'].str.contains("Family history")]['fid'].unique())

# %%
fh.extend(fid[fid['fact'].str.contains("FH")]['fid'].unique())

# %%
fh
# Out:
# ['COND_4334340',
#  'COND_4326027',
#  'COND_4327586',
#  'COND_764551',
#  'COND_4051241',
#  'COND_762448',
#  'COND_4332372',
#  'COND_4182335',
#  'COND_37119239',
#  'COND_46270012',
#  'COND_4167217',
#  'COND_4169823',
#  'COND_4324464',
#  'COND_4135415',
#  'COND_46270577',
#  'COND_4124794',
#  'COND_4083519',
#  'COND_4325372',
#  'COND_4323775',
#  'COND_4327587',
#  'COND_4232398',
#  'COND_4326678',
#  'COND_46269913',
#  'COND_46270582',
#  'COND_46270007',
#  'COND_763010',
#  'COND_4326671',
#  'COND_4326004',
#  'COND_764559',
#  'COND_4203375',
#  'COND_4198920',
#  'COND_4160978',
#  'COND_4051568',
#  'COND_761094',
#  'COND_4200319',
#  'COND_4178537',
#  'COND_762366',
#  'COND_42535500',
#  'COND_44782797',
#  'COND_764756',
#  'COND_4169009',
#  'COND_4333615',
#  'COND_4050793',
#  'COND_4214299',
#  'COND_4171594',
#  'COND_4331069',
#  'COND_4160280',
#  'COND_4141780',
#  'COND_36683300',
#  'COND_4295015',
#  'COND_4213257',
#  'COND_37117072',
# ...

# %%
fh=list(fid[fid['fact'].str.contains("Family history")]['fact'].unique())

# %%
fh.extend(fid[fid['fact'].str.contains("FH")]['fact'].unique())

# %%
fh
# Out:
# ['Family history of diabetes mellitus type 2',
#  'Family history of coronary arteriosclerosis',
#  'Family history of thromboembolic disorder',
#  'Family history of vitamin D deficiency',
#  'Family history of asthma',
#  'Family history of lactose intolerance',
#  'Family history of aneurysm of artery',
#  'Family history of ischemic heart disease',
#  'Family history of hyperlipidemia',
#  'Family history of Hashimoto thyroiditis',
#  'Family history of clinical finding',
#  'Family history of learning disability',
#  'Family history of conduction disorder of the heart',
#  'Family history of autism',
#  'Family history of Marfan syndrome',
#  'Family history of kidney disease',
#  'Family history of disorder',
#  'Family history of celiac disease',
#  'Family history of malignant neoplasm of skin',
#  'Family history of seizure disorder',
#  'Family history of hearing loss',
#  'Family history of genetic disorder carrier',
#  'Family history of blood coagulation disorder',
# ...

# %%
pd.Series(fh).to_csv('family_history.csv',index=False)

# %%
fid[fid['fact'].str.contains("eating")]['fact'].unique()
# Out:
# array(['Excessive sweating', 'Excessive eating - polyphagia',
#        'Toxic effect from eating mushrooms',
#        'Inappropriate diet and eating habits', 'Sweating', 'Overeating',
#        'Binge eating disorder', 'History of eating disorder',
#        'Family history of eating disorder', 'Psychogenic overeating',
#        'Absence of sweating',
#        "Work related or medical disability examination by other than the treating physician that includes: Completion of a medical history commensurate with the patient's condition; Performance of an examination commensurate with the patient's condition; Formulat",
#        'Toxic effect from eating berries AND/OR other plants',
#        'Finding of eating pattern', 'Sweating fever', 'Difficulty eating',
#        'Anorexia nervosa, binge-eating purging type',
#        'Fear of eating in public',
#        'Social phobia, fear of eating in public',
#        'Nocturnal sleep-related eating disorder'], dtype=object)

# %%
fid=fid[fid['fid'].str.startswith('COND')]

# %%
ob=list(fid[fid['fact'].str.contains("weight")]['fid'].unique())

# %%
ob.extend(fid[fid['fact'].str.contains("Weight")]['fid'].unique())

# %%
ob.extend(fid[fid['fact'].str.contains("obesity")]['fid'].unique())

# %%
ob.extend(fid[fid['fact'].str.contains("Obesity")]['fid'].unique())

# %%
len(ob)
# Out:
# 51

# %%
list(fid[fid['fid'].isin(ob)]['fid'].unique())
# Out:
# ['COND_439141',
#  'COND_42872417',
#  'COND_435372',
#  'COND_433736',
#  'COND_437525',
#  'COND_40481140',
#  'COND_434005',
#  'COND_42872460',
#  'COND_4217557',
#  'COND_36712780',
#  'COND_37018860',
#  'COND_4171115',
#  'COND_4270276',
#  'COND_4173323',
#  'COND_4074313',
#  'COND_4051566',
#  'COND_40491502',
#  'COND_4060985',
#  'COND_4079858',
#  'COND_4059799',
#  'COND_4325353',
#  'COND_4060705',
#  'COND_4149455',
#  'COND_4204347',
#  'COND_435928',
#  'COND_4118264',
#  'COND_4309406',
#  'COND_4100857',
#  'COND_42538717',
#  'COND_4097996',
#  'COND_4143827',
#  'COND_4008159',
#  'COND_4116707',
#  'COND_4276723',
#  'COND_4022831',
#  'COND_4171317',
#  'COND_4061230',
#  'COND_4160821',
#  'COND_4195545',
#  'COND_45771484',
#  'COND_4175214',
#  'COND_4330994',
#  'COND_4097929',
#  'COND_4087487',
#  'COND_4149609',
#  'COND_42539369',
#  'COND_4143858',
#  'COND_4112788',
#  'COND_4220527',
#  'COND_46270518',
#  'COND_4163032']

# %%
=====Ly's list==============
